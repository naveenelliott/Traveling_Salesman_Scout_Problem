# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import time
import re

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# STEP 1: Get team URLs from league page
def get_team_urls(league_url):
    res = requests.get(league_url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")


    team_links = soup.select('td.hauptlink.no-border-links a')
    
    team_urls = []
    for link in team_links:
        href = link.get("href")
        if href and "/startseite/verein/" in href:
            # Ensure full URL and keep ?saison_id in it
            full_url = f"https://www.transfermarkt.us{href}"
            team_urls.append(full_url)
    return list(set(team_urls))  # remove duplicates

# %%
league_urls = {
    "USL1": "https://www.transfermarkt.us/usl-league-one/startseite/wettbewerb/USC3"
}

all_data = []

team_urls = get_team_urls(league_urls["USL1"])

# %%
team_urls
# Out:
# ['https://www.transfermarkt.us/portland-hearts-of-pine/startseite/verein/124312/saison_id/2024',
#  'https://www.transfermarkt.us/one-knoxville-sc/startseite/verein/102031/saison_id/2024',
#  'https://www.transfermarkt.us/fc-naples/startseite/verein/120328/saison_id/2024',
#  'https://www.transfermarkt.us/texoma-fc/startseite/verein/115284/saison_id/2024',
#  'https://www.transfermarkt.us/south-georgia-tormenta-fc/startseite/verein/58894/saison_id/2024',
#  'https://www.transfermarkt.us/av-alta-fc/startseite/verein/119858/saison_id/2024',
#  'https://www.transfermarkt.us/greenville-triumph-sc/startseite/verein/69055/saison_id/2024',
#  'https://www.transfermarkt.us/spokane-velocity-fc/startseite/verein/114568/saison_id/2024',
#  'https://www.transfermarkt.us/charlotte-independence/startseite/verein/46717/saison_id/2024',
#  'https://www.transfermarkt.us/union-omaha/startseite/verein/77059/saison_id/2024',
#  'https://www.transfermarkt.us/richmond-kickers/startseite/verein/16931/saison_id/2024',
#  'https://www.transfermarkt.us/westchester-sc/startseite/verein/122406/saison_id/2024',
#  'https://www.transfermarkt.us/chattanooga-red-wolves-sc/startseite/verein/69398/saison_id/2024',
#  'https://www.transfermarkt.us/forward-madison-fc/startseite/verein/69748/saison_id/2024']

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

def extract_player_market_values(team_url):
    res = requests.get(team_url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")

    players = []

    # Find the player rows in the squad table
    table = soup.find("table", class_="items")
    if not table:
        return []

    rows = table.find_all("tr", class_=["odd", "even"])

    for row in rows:
        name_tag = row.find("td", class_="hauptlink")
        value_tag = row.find("td", class_="rechts hauptlink")

        if not name_tag or not value_tag:
            continue

        player_name = name_tag.get_text(strip=True)
        market_value = value_tag.get_text(strip=True)

        # Optional: get player detail page link
        link_tag = name_tag.find("a")
        player_link = (
            "https://www.transfermarkt.us" + link_tag["href"]
            if link_tag and link_tag.has_attr("href")
            else None
        )

        players.append({
            "player_name": player_name,
            "market_value": market_value,
            "player_link": player_link
        })

    return players

overall_data = []
# Example usage
for team_url in team_urls:
    players = extract_player_market_values(team_url)

    print(f"Team URL: {team_url}")
    print(f"Number of players scraped: {len(players)}")
    if players:
        print(players[0])  # Print one player's data as a sanity check

    overall_data.append({
        "team_url": team_url,
        "players": players
    })
    # Optional: Sleep to avoid overwhelming the server
    time.sleep(1)
# Out:
# Team URL: https://www.transfermarkt.us/portland-hearts-of-pine/startseite/verein/124312/saison_id/2024
# Number of players scraped: 23
# {'player_name': 'Hunter Morse', 'market_value': '€10k', 'player_link': 'https://www.transfermarkt.us/hunter-morse/profil/spieler/637163'}
# Team URL: https://www.transfermarkt.us/one-knoxville-sc/startseite/verein/102031/saison_id/2024
# Number of players scraped: 24
# {'player_name': 'Sean Lewis', 'market_value': '€100k', 'player_link': 'https://www.transfermarkt.us/sean-lewis/profil/spieler/431278'}
# Team URL: https://www.transfermarkt.us/fc-naples/startseite/verein/120328/saison_id/2024
# Number of players scraped: 23
# {'player_name': 'Lalo Delgado', 'market_value': '€150k', 'player_link': 'https://www.transfermarkt.us/lalo-delgado/profil/spieler/748991'}
# Team URL: https://www.transfermarkt.us/texoma-fc/startseite/verein/115284/saison_id/2024
# Number of players scraped: 26
# {'player_name': 'Mason McCready', 'market_value': '€75k', 'player_link': 'https://www.transfermarkt.us/mason-mccready/profil/spieler/830333'}
# Team URL: https://www.transfermarkt.us/south-georgia-tormenta-fc/startseite/verein/58894/saison_id/2024
# Number of players scraped: 24
# {'player_name': 'Austin Pack', 'market_value': '€175k', 'player_link': 'https://www.transfermarkt.us/austin-pack/profil/spieler/458524'}
# Team URL: https://www.transfermarkt.us/av-alta-fc/startseite/verein/119858/saison_id/2024
# Number of players scraped: 25
# {'player_name': 'Carlos Ávilez', 'market_value': '€125k', 'player_link': 'https://www.transfermarkt.us/carlos-avilez/profil/spieler/354311'}
# Team URL: https://www.transfermarkt.us/greenville-triumph-sc/startseite/verein/69055/saison_id/2024
# Number of players scraped: 24
# {'player_name': 'Gunther Rankenburg', 'market_value': '€100k', 'player_link': 'https://www.transfermarkt.us/gunther-rankenburg/profil/spieler/635738'}
# Team URL: https://www.transfermarkt.us/spokane-velocity-fc/startseite/verein/114568/saison_id/2024
# Number of players scraped: 24
# {'player_name': 'Carlos Merancio', 'market_value': '€150k', 'player_link': 'https://www.transfermarkt.us/carlos-merancio/profil/spieler/656433'}
# Team URL: https://www.transfermarkt.us/charlotte-independence/startseite/verein/46717/saison_id/2024
# Number of players scraped: 24
# {'player_name': 'Matt Levy', 'market_value': '€125k', 'player_link': 'https://www.transfermarkt.us/matt-levy/profil/spieler/1167713'}
# Team URL: https://www.transfermarkt.us/union-omaha/startseite/verein/77059/saison_id/2024
# Number of players scraped: 24
# {'player_name': 'Rashid Nuhu', 'market_value': '€150k', 'player_link': 'https://www.transfermarkt.us/rashid-nuhu/profil/spieler/674379'}
# Team URL: https://www.transfermarkt.us/richmond-kickers/startseite/verein/16931/saison_id/2024
# Number of players scraped: 26
# {'player_name': 'James Sneddon', 'market_value': '€100k', 'player_link': 'https://www.transfermarkt.us/james-sneddon/profil/spieler/1147673'}
# Team URL: https://www.transfermarkt.us/westchester-sc/startseite/verein/122406/saison_id/2024
# Number of players scraped: 0
# Team URL: https://www.transfermarkt.us/chattanooga-red-wolves-sc/startseite/verein/69398/saison_id/2024
# Number of players scraped: 22
# {'player_name': 'Jason Smith', 'market_value': '€100k', 'player_link': 'https://www.transfermarkt.us/jason-smith/profil/spieler/1305218'}
# Team URL: https://www.transfermarkt.us/forward-madison-fc/startseite/verein/69748/saison_id/2024
# Number of players scraped: 23
# {'player_name': 'Bernd Schipmann', 'market_value': '€150k', 'player_link': 'https://www.transfermarkt.us/bernd-schipmann/profil/spieler/124677'}

# %%
flattened_data = []

for team in overall_data:
    for player in team["players"]:
        flattened_data.append({
            "team_url": team["team_url"],
            **player
        })

overall_df = pd.DataFrame(flattened_data)
overall_df
# Out:
#                                               team_url         player_name  \
# 0    https://www.transfermarkt.us/portland-hearts-o...        Hunter Morse
# 1    https://www.transfermarkt.us/portland-hearts-o...        Kash Oladapo
# 2    https://www.transfermarkt.us/portland-hearts-o...        Kemali Green
# 3    https://www.transfermarkt.us/portland-hearts-o...        Sean Vinberg
# 4    https://www.transfermarkt.us/portland-hearts-o...      Shandon Wright
# ..                                                 ...                 ...
# 307  https://www.transfermarkt.us/forward-madison-f...       Derek Gebhard
# 308  https://www.transfermarkt.us/forward-madison-f...  Garrett McLaughlin
# 309  https://www.transfermarkt.us/forward-madison-f...      Juan Galindrez
# 310  https://www.transfermarkt.us/forward-madison-f...      Adrien Graffin
# 311  https://www.transfermarkt.us/forward-madison-f...       Lucca Dourado
#
#     market_value                                        player_link
# 0           €10k  https://www.transfermarkt.us/hunter-morse/prof...
# 1              -  https://www.transfermarkt.us/kash-oladapo/prof...
# 2           €75k  https://www.transfermarkt.us/kemali-green/prof...
# 3           €75k  https://www.transfermarkt.us/sean-vinberg/prof...
# 4           €50k  https://www.transfermarkt.us/shandon-wright/pr...
# ..           ...                                                ...
# 307        €200k  https://www.transfermarkt.us/derek-gebhard/pro...
# 308        €175k  https://www.transfermarkt.us/garrett-mclaughli...
# 309        €150k  https://www.transfermarkt.us/juan-galindrez/pr...
# 310         €25k  https://www.transfermarkt.us/adrien-graffin/pr...
# 311            -  https://www.transfermarkt.us/lucca-dourado/pro...
#
# [312 rows x 4 columns]

# %%
overall_df.to_csv("usl1_market_values_1.csv", index=False)

# %%
not_scraped = [
 'https://www.transfermarkt.us/westchester-sc/startseite/verein/122406/saison_id/2024']

# %%
overall_data = []
# Example usage
for team_url in not_scraped:
    players = extract_player_market_values(team_url)

    print(f"Team URL: {team_url}")
    print(f"Number of players scraped: {len(players)}")
    if players:
        print(players[0])  # Print one player's data as a sanity check

    overall_data.append({
        "team_url": team_url,
        "players": players
    })
    # Optional: Sleep to avoid overwhelming the server
    time.sleep(1)
# Out:
# Team URL: https://www.transfermarkt.us/westchester-sc/startseite/verein/122406/saison_id/2024
# Number of players scraped: 24
# {'player_name': 'Dane Jacomen', 'market_value': '€100k', 'player_link': 'https://www.transfermarkt.us/dane-jacomen/profil/spieler/993314'}

# %%
flattened_data = []

for team in overall_data:
    for player in team["players"]:
        flattened_data.append({
            "team_url": team["team_url"],
            **player
        })

overall_df = pd.DataFrame(flattened_data)
print(overall_df)
overall_df.to_csv("usl1_market_values_2.csv", index=False)
# Out:
#                                              team_url           player_name  \
# 0   https://www.transfermarkt.us/westchester-sc/st...          Dane Jacomen
# 1   https://www.transfermarkt.us/westchester-sc/st...     Andrew Hammersley
# 2   https://www.transfermarkt.us/westchester-sc/st...         Rashid Tetteh
# 3   https://www.transfermarkt.us/westchester-sc/st...          Tobi Adewole
# 4   https://www.transfermarkt.us/westchester-sc/st...  Andrew Jean-Baptiste
# 5   https://www.transfermarkt.us/westchester-sc/st...          Bobby Pierre
# 6   https://www.transfermarkt.us/westchester-sc/st...       Sebastián Palma
# 7   https://www.transfermarkt.us/westchester-sc/st...           Noah Powder
# 8   https://www.transfermarkt.us/westchester-sc/st...            Josh Drack
# 9   https://www.transfermarkt.us/westchester-sc/st...        Kemar Lawrence
# 10  https://www.transfermarkt.us/westchester-sc/st...         Stephen Payne
# 11  https://www.transfermarkt.us/westchester-sc/st...          Joel Johnson
# 12  https://www.transfermarkt.us/westchester-sc/st...         Conor McGlynn
# 13  https://www.transfermarkt.us/westchester-sc/st...          Ermin Mackic
# 14  https://www.transfermarkt.us/westchester-sc/st...      Samuel Greenberg
# 15  https://www.transfermarkt.us/westchester-sc/st...         Daniel Bouman
# 16  https://www.transfermarkt.us/westchester-sc/st...      Jonathan Bolanos
# 17  https://www.transfermarkt.us/westchester-sc/st...         Bryan Vasquez
# 18  https://www.transfermarkt.us/westchester-sc/st...           Dean Guezen
# 19  https://www.transfermarkt.us/westchester-sc/st...         Prince Saydee
# 20  https://www.transfermarkt.us/westchester-sc/st...          Mink Peeters
# 21  https://www.transfermarkt.us/westchester-sc/st...   Juan Carlos Obregon
# 22  https://www.transfermarkt.us/westchester-sc/st...         Samory Powder
# 23  https://www.transfermarkt.us/westchester-sc/st...      Koen Blommestijn
#
#    market_value                                        player_link
# 0         €100k  https://www.transfermarkt.us/dane-jacomen/prof...
# 1             -  https://www.transfermarkt.us/andrew-hammersley...
# 2         €125k  https://www.transfermarkt.us/rashid-tetteh/pro...
# 3         €100k  https://www.transfermarkt.us/tobi-adewole/prof...
# 4         €100k  https://www.transfermarkt.us/andrew-jean-bapti...
# 5          €75k  https://www.transfermarkt.us/bobby-pierre/prof...
# 6          €50k  https://www.transfermarkt.us/sebastian-palma/p...
# 7         €175k  https://www.transfermarkt.us/noah-powder/profi...
# 8         €100k  https://www.transfermarkt.us/josh-drack/profil...
# 9         €100k  https://www.transfermarkt.us/kemar-lawrence/pr...
# 10        €150k  https://www.transfermarkt.us/stephen-payne/pro...
# 11        €125k  https://www.transfermarkt.us/joel-johnson/prof...
# 12        €150k  https://www.transfermarkt.us/conor-mcglynn/pro...
# 13         €25k  https://www.transfermarkt.us/ermin-mackic/prof...
# 14            -  https://www.transfermarkt.us/samuel-greenberg/...
# 15        €100k  https://www.transfermarkt.us/daniel-bouman/pro...
# 16        €150k  https://www.transfermarkt.us/jonathan-bolanos/...
# 17            -  https://www.transfermarkt.us/bryan-vasquez/pro...
# 18        €100k  https://www.transfermarkt.us/dean-guezen/profi...
# 19        €100k  https://www.transfermarkt.us/prince-saydee/pro...
# 20         €50k  https://www.transfermarkt.us/mink-peeters/prof...
# 21        €250k  https://www.transfermarkt.us/juan-carlos-obreg...
# 22        €100k  https://www.transfermarkt.us/samory-powder/pro...
# 23        €100k  https://www.transfermarkt.us/koen-blommestijn/...
